# %% [markdown]
# # Multiclass Support Vector Machine exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# In this exercise you will:
#
# - implement a fully-vectorized **loss function** for the SVM
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** using numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
# Run some setup code for this notebook.

import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# This is a bit of magic to make matplotlib figures appear inline in the
# notebook rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## CIFAR-10 Data Loading and Preprocessing

# %%
# Load the raw CIFAR-10 data.
cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

# As a sanity check, we print out the size of the training and test data.
print 'Training data shape: ', X_train.shape
print 'Training labels shape: ', y_train.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
# Out:
# Training data shape:  (50000, 32, 32, 3)
# Training labels shape:  (50000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %%
# Visualize some examples from the dataset.
# We show a few examples of training images from each class.
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 7
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
# Split the data into train, val, and test sets. In addition we will
# create a small development set as a subset of the training data;
# we can use this for development so our code runs faster.
num_training = 49000
num_validation = 1000
num_test = 1000
num_dev = 500

# Our validation set will be num_validation points from the original
# training set.
mask = range(num_training, num_training + num_validation)
X_val = X_train[mask]
y_val = y_train[mask]

# Our training set will be the first num_train points from the original
# training set.
mask = range(num_training)
X_train = X_train[mask]
y_train = y_train[mask]

# We will also make a development set, which is a small subset of
# the training set.
mask = np.random.choice(num_training, num_dev, replace=False)
X_dev = X_train[mask]
y_dev = y_train[mask]

# We use the first num_test points of the original test set as our
# test set.
mask = range(num_test)
X_test = X_test[mask]
y_test = y_test[mask]

print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
# Out:
# Train data shape:  (49000, 32, 32, 3)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 32, 32, 3)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 32, 32, 3)
# Test labels shape:  (1000,)

# %%
# Preprocessing: reshape the image data into rows
X_train = np.reshape(X_train, (X_train.shape[0], -1))
X_val = np.reshape(X_val, (X_val.shape[0], -1))
X_test = np.reshape(X_test, (X_test.shape[0], -1))
X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))

# As a sanity check, print out the shapes of the data
print 'Training data shape: ', X_train.shape
print 'Validation data shape: ', X_val.shape
print 'Test data shape: ', X_test.shape
print 'dev data shape: ', X_dev.shape
# Out:
# Training data shape:  (49000, 3072)
# Validation data shape:  (1000, 3072)
# Test data shape:  (1000, 3072)
# dev data shape:  (500, 3072)

# %%
# Preprocessing: subtract the mean image
# first: compute the image mean based on the training data
mean_image = np.mean(X_train, axis=0)
print mean_image[:10] # print a few of the elements
plt.figure(figsize=(4,4))
plt.imshow(mean_image.reshape((32,32,3)).astype('uint8')) # visualize the mean image
plt.show()
# Out:
# [ 130.64189796  135.98173469  132.47391837  130.05569388  135.34804082
#   131.75402041  130.96055102  136.14328571  132.47636735  131.48467347]

# %%
# second: subtract the mean image from train and test data
X_train -= mean_image
X_val -= mean_image
X_test -= mean_image
X_dev -= mean_image

# %%
# third: append the bias dimension of ones (i.e. bias trick) so that our SVM
# only has to worry about optimizing a single weight matrix W.
X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])

print X_train.shape, X_val.shape, X_test.shape, X_dev.shape
# Out:
# (49000, 3073) (1000, 3073) (1000, 3073) (500, 3073)

# %% [markdown]
# ## SVM Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/linear_svm.py**.
#
# As you can see, we have prefilled the function `compute_loss_naive` which uses for loops to evaluate the multiclass SVM loss function.

# %%
# Evaluate the naive implementation of the loss we provided for you:
from cs231n.classifiers.linear_svm import svm_loss_naive
import time

# generate a random SVM weight matrix of small numbers
W = np.random.randn(3073, 10) * 0.0001 

loss, grad = svm_loss_naive(W, X_dev, y_dev, 0.00001)
print 'loss: %f' % (loss, )
# Out:
# loss: 9.212794

# %% [markdown]
# The `grad` returned from the function above is right now all zero. Derive and implement the gradient for the SVM cost function and implement it inline inside the function `svm_loss_naive`. You will find it helpful to interleave your new code inside the existing function.
#
# To check that you have correctly implemented the gradient correctly, you can numerically estimate the gradient of the loss function and compare the numeric estimate to the gradient that you computed. We have provided code that does this for you:

# %%
# Once you've implemented the gradient, recompute it with the code below
# and gradient check it with the function we provided for you

# Compute the loss and its gradient at W.
loss, grad = svm_loss_naive(W, X_dev, y_dev, 0.0)

# Numerically compute the gradient along several randomly chosen dimensions, and
# compare them with your analytically computed gradient. The numbers should match
# almost exactly along all dimensions.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: svm_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad)
print("")
# do the gradient check once again with regularization turned on
# you didn't forget the regularization gradient did you?
loss, grad = svm_loss_naive(W, X_dev, y_dev, 1e2)
f = lambda w: svm_loss_naive(w, X_dev, y_dev, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad)
# Out:
# numerical: -12.823587 analytic: -12.823587, relative error: 5.390123e-12
# numerical: -40.802251 analytic: -40.802251, relative error: 4.333723e-12
# numerical: 2.212306 analytic: 2.212306, relative error: 3.670746e-11
# numerical: -4.043191 analytic: -4.043191, relative error: 3.787903e-11
# numerical: -6.763618 analytic: -6.763618, relative error: 4.149179e-11
# numerical: 11.610516 analytic: 11.610516, relative error: 7.061508e-12
# numerical: 18.341649 analytic: 18.341649, relative error: 5.274356e-13
# numerical: -10.745930 analytic: -10.745930, relative error: 3.974951e-11
# numerical: 6.652004 analytic: 6.745739, relative error: 6.996337e-03
# numerical: 1.630077 analytic: 1.630077, relative error: 3.078343e-10
#
# numerical: 33.904067 analytic: 33.904067, relative error: 1.962896e-11
# numerical: -5.764193 analytic: -5.764193, relative error: 4.590514e-11
# numerical: 14.348648 analytic: 14.383496, relative error: 1.212869e-03
# numerical: -7.638202 analytic: -7.638202, relative error: 2.244806e-12
# numerical: 16.491759 analytic: 16.491759, relative error: 5.051252e-12
# numerical: -1.849067 analytic: -1.849067, relative error: 1.073601e-10
# numerical: 2.980866 analytic: 2.980866, relative error: 5.214127e-11
# numerical: -55.343164 analytic: -55.343164, relative error: 1.010546e-12
# numerical: 13.051681 analytic: 12.941378, relative error: 4.243538e-03
# numerical: -18.712480 analytic: -18.712480, relative error: 1.831247e-11

# %% [markdown]
# ### Inline Question 1:
# It is possible that once in a while a dimension in the gradcheck will not match exactly. What could such a discrepancy be caused by? Is it a reason for concern? What is a simple example in one dimension where a gradient check could fail? *Hint: the SVM loss function is not strictly speaking differentiable*
#
# **Your Answer:** *fill this in.*

# %%
# Next implement the function svm_loss_vectorized; for now only compute the loss;
# we will implement the gradient in a moment.
tic = time.time()
loss_naive, grad_naive = svm_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'Naive loss: %e computed in %fs' % (loss_naive, toc - tic)

from cs231n.classifiers.linear_svm import svm_loss_vectorized
tic = time.time()
loss_vectorized, _ = svm_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'Vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic)

# The losses should match but your vectorized implementation should be much faster.
print 'difference: %f' % (loss_naive - loss_vectorized)
# Out:
# Naive loss: 9.212794e+00 computed in 1.664306s
# (500, 10)
# (500,)
# Vectorized loss: 9.212794e+00 computed in 0.253238s
# difference: 0.000000

# %%
# Complete the implementation of svm_loss_vectorized, and compute the gradient
# of the loss function in a vectorized way.

# The naive implementation and the vectorized implementation should match, but
# the vectorized version should still be much faster.
tic = time.time()
_, grad_naive = svm_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'Naive loss and gradient: computed in %fs' % (toc - tic)

tic = time.time()
_, grad_vectorized = svm_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'Vectorized loss and gradient: computed in %fs' % (toc - tic)

# The loss is a single number, so it is easy to compare the values computed
# by the two implementations. The gradient on the other hand is a matrix, so
# we use the Frobenius norm to compare them.
difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print 'difference: %f' % difference
# Out:
# Naive loss and gradient: computed in 0.269778s
# (500, 10)
# (500,)
# Vectorized loss and gradient: computed in 0.013226s
# difference: 0.000000

# %% [markdown]
# ### Stochastic Gradient Descent
#
# We now have vectorized and efficient expressions for the loss, the gradient and our gradient matches the numerical gradient. We are therefore ready to do SGD to minimize the loss.

# %%
# In the file linear_classifier.py, implement SGD in the function
# LinearClassifier.train() and then run it with the code below.
from cs231n.classifiers import LinearSVM
svm = LinearSVM()
tic = time.time()
loss_hist = svm.train(X_train, y_train, learning_rate=1e-7, reg=5e4,
                      num_iters=1500, verbose=True)
toc = time.time()
print 'That took %fs' % (toc - tic)
# Out:
# iteration 0 / 1500: loss 794.919922
# iteration 100 / 1500: loss 779.052820
# iteration 200 / 1500: loss 774.399143
# iteration 300 / 1500: loss 770.897795
# iteration 400 / 1500: loss 767.787180
# iteration 500 / 1500: loss 765.119147
# iteration 600 / 1500: loss 762.898995
# iteration 700 / 1500: loss 761.288392
# iteration 800 / 1500: loss 758.911300
# iteration 900 / 1500: loss 757.760302
# iteration 1000 / 1500: loss 756.087178
# iteration 1100 / 1500: loss 754.580408
# iteration 1200 / 1500: loss 751.586949
# iteration 1300 / 1500: loss 750.393068
# iteration 1400 / 1500: loss 749.563186
# That took 8.330514s

# %%
# A useful debugging strategy is to plot the loss as a function of
# iteration number:
plt.plot(loss_hist)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %%
# Write the LinearSVM.predict function and evaluate the performance on both the
# training and validation set
y_train_pred = svm.predict(X_train)
print 'training accuracy: %f' % (np.mean(y_train == y_train_pred), )
y_val_pred = svm.predict(X_val)
print 'validation accuracy: %f' % (np.mean(y_val == y_val_pred), )
# Out:
# training accuracy: 0.307959
# validation accuracy: 0.310000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of about 0.4 on the validation set.
learning_rates = [1e-7, 5e-7, 1e-5, 5e-5, 1e-6, 5e-6]
regularization_strengths = [1e4, 5e4, 1e5]

# results is dictionary mapping tuples of the form
# (learning_rate, regularization_strength) to tuples of the form
# (training_accuracy, validation_accuracy). The accuracy is simply the fraction
# of data points that are correctly classified.
results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.
best_svm = None # The LinearSVM object that achieved the highest validation rate.

################################################################################
# TODO:                                                                        #
# Write code that chooses the best hyperparameters by tuning on the validation #
# set. For each combination of hyperparameters, train a linear SVM on the      #
# training set, compute its accuracy on the training and validation sets, and  #
# store these numbers in the results dictionary. In addition, store the best   #
# validation accuracy in best_val and the LinearSVM object that achieves this  #
# accuracy in best_svm.                                                        #
#                                                                              #
# Hint: You should use a small value for num_iters as you develop your         #
# validation code so that the SVMs don't take much time to train; once you are #
# confident that your validation code works, you should rerun the validation   #
# code with a larger value for num_iters.                                      #
################################################################################
best_lr = 0
best_reg = 0
for i in range(10):
    print("Loop", i)
    print("Learning rates:", learning_rates)
    print("Regularization strenghts:",regularization_strengths)
    for learn_rate in learning_rates:
        for reg in regularization_strengths:
            print("Learning rate:", learn_rate, "Regularization strength:", reg)
            svm = LinearSVM()
            loss_hist = svm.train(X_train, y_train, learning_rate=learn_rate, reg=reg,
                          num_iters=1500, verbose=False)

            y_train_pred = svm.predict(X_train)
            y_val_pred = svm.predict(X_val)

            training_acc = np.mean(y_train == y_train_pred)
            val_acc = np.mean(y_val == y_val_pred)

            results[learn_rate, reg] = training_acc, val_acc

            if val_acc > best_val:
                best_val = val_acc
                best_svm = svm
                best_lr = learn_rate
                best_reg = reg

            #print("val_acc:",val_acc)
            print("results[learn_rate, reg]", results[learn_rate, reg])
            print("")
            
    # we refill learning rates and regs with similar values as the best ones from last loop
    # this way we can automate the trial and error hyperparamenter search process
    learning_rates = [best_lr - 0.5*best_lr, best_lr - 0.3*best_lr, best_lr, best_lr + 0.3*best_lr, best_lr + 0.5*best_lr]
    regularization_strengths = [best_reg - 0.5*best_reg, best_reg - 0.3*best_reg, best_reg, best_reg + 0.3*best_reg, best_reg + 0.5*best_reg]

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr,
                reg,
                train_accuracy,
                val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# ('Loop', 0)
# ('Learning rates:', [1e-07, 5e-07, 1e-05, 5e-05, 1e-06, 5e-06])
# ('Regularization strenghts:', [10000.0, 50000.0, 100000.0])
# ('Learning rate:', 1e-07, 'Regularization strength:', 10000.0)
# ('val_acc:', 0.216)
# ('results[learn_rate, reg]', (0.21726530612244899, 0.216))
#
# ('Learning rate:', 1e-07, 'Regularization strength:', 50000.0)
# ('val_acc:', 0.253)
# ('results[learn_rate, reg]', (0.21718367346938774, 0.253))
#
# ('Learning rate:', 1e-07, 'Regularization strength:', 100000.0)
# ('val_acc:', 0.22600000000000001)
# ('results[learn_rate, reg]', (0.21828571428571428, 0.22600000000000001))
#
# ('Learning rate:', 5e-07, 'Regularization strength:', 10000.0)
# ('val_acc:', 0.29299999999999998)
# ('results[learn_rate, reg]', (0.28467346938775512, 0.29299999999999998))
#
# ('Learning rate:', 5e-07, 'Regularization strength:', 50000.0)
# ('val_acc:', 0.27900000000000003)
# ('results[learn_rate, reg]', (0.27300000000000002, 0.27900000000000003))
#
# ('Learning rate:', 5e-07, 'Regularization strength:', 100000.0)
# ('val_acc:', 0.26800000000000002)
# ('results[learn_rate, reg]', (0.27512244897959182, 0.26800000000000002))
#
# ('Learning rate:', 1e-05, 'Regularization strength:', 10000.0)
# ('val_acc:', 0.26400000000000001)
# ('results[learn_rate, reg]', (0.27338775510204083, 0.26400000000000001))
#
# ('Learning rate:', 1e-05, 'Regularization strength:', 50000.0)
# ('val_acc:', 0.27800000000000002)
# ('results[learn_rate, reg]', (0.26875510204081632, 0.27800000000000002))
#
# ('Learning rate:', 1e-05, 'Regularization strength:', 100000.0)
# ('val_acc:', 0.29899999999999999)
# ('results[learn_rate, reg]', (0.27889795918367349, 0.29899999999999999))
#
# ('Learning rate:', 5e-05, 'Regularization strength:', 10000.0)
# ('val_acc:', 0.27800000000000002)
# ('results[learn_rate, reg]', (0.28212244897959182, 0.27800000000000002))
#
# ('Learning rate:', 5e-05, 'Regularization strength:', 50000.0)
# ('val_acc:', 0.316)
# ('results[learn_rate, reg]', (0.29785714285714288, 0.316))
#
# ('Learning rate:', 5e-05, 'Regularization strength:', 100000.0)
# ('val_acc:', 0.29699999999999999)
# ('results[learn_rate, reg]', (0.29063265306122449, 0.29699999999999999))
#
# ('Learning rate:', 1e-06, 'Regularization strength:', 10000.0)
# ('val_acc:', 0.30399999999999999)
# ('results[learn_rate, reg]', (0.30167346938775508, 0.30399999999999999))
#
# ('Learning rate:', 1e-06, 'Regularization strength:', 50000.0)
# ('val_acc:', 0.31)
# ('results[learn_rate, reg]', (0.30255102040816328, 0.31))
#
# ('Learning rate:', 1e-06, 'Regularization strength:', 100000.0)
# ('val_acc:', 0.312)
# ('results[learn_rate, reg]', (0.3046938775510204, 0.312))
#
# ('Learning rate:', 5e-06, 'Regularization strength:', 10000.0)
# ('val_acc:', 0.307)
# ('results[learn_rate, reg]', (0.2939591836734694, 0.307))
#
# ('Learning rate:', 5e-06, 'Regularization strength:', 50000.0)
# ('val_acc:', 0.26800000000000002)
# ('results[learn_rate, reg]', (0.25134693877551023, 0.26800000000000002))
#
# ('Learning rate:', 5e-06, 'Regularization strength:', 100000.0)
# ('val_acc:', 0.29599999999999999)
# ('results[learn_rate, reg]', (0.27906122448979592, 0.29599999999999999))
#
# ('Loop', 1)
# ('Learning rates:', [2.5e-05, 3.5000000000000004e-05, 6.500000000000001e-05, 7.500000000000001e-05])
# ('Regularization strenghts:', [25000.0, 35000.0, 65000.0, 75000.0])
# ('Learning rate:', 2.5e-05, 'Regularization strength:', 25000.0)
# ('val_acc:', 0.253)
# ('results[learn_rate, reg]', (0.23353061224489796, 0.253))
#
# ('Learning rate:', 2.5e-05, 'Regularization strength:', 35000.0)
# ('val_acc:', 0.23599999999999999)
# ('results[learn_rate, reg]', (0.23042857142857143, 0.23599999999999999))
#
# ('Learning rate:', 2.5e-05, 'Regularization strength:', 65000.0)
# ('val_acc:', 0.27500000000000002)
# ('results[learn_rate, reg]', (0.29714285714285715, 0.27500000000000002))
#
# ('Learning rate:', 2.5e-05, 'Regularization strength:', 75000.0)
# ('val_acc:', 0.28000000000000003)
# ('results[learn_rate, reg]', (0.298265306122449, 0.28000000000000003))
#
# ('Learning rate:', 3.5000000000000004e-05, 'Regularization strength:', 25000.0)
# ('val_acc:', 0.27900000000000003)
# ('results[learn_rate, reg]', (0.25822448979591839, 0.27900000000000003))
#
# ('Learning rate:', 3.5000000000000004e-05, 'Regularization strength:', 35000.0)
# ('val_acc:', 0.29499999999999998)
# ('results[learn_rate, reg]', (0.30797959183673468, 0.29499999999999998))
#
# ('Learning rate:', 3.5000000000000004e-05, 'Regularization strength:', 65000.0)
# ('val_acc:', 0.249)
# ('results[learn_rate, reg]', (0.251, 0.249))
#
# ('Learning rate:', 3.5000000000000004e-05, 'Regularization strength:', 75000.0)
# ('val_acc:', 0.30399999999999999)
# ('results[learn_rate, reg]', (0.29375510204081634, 0.30399999999999999))
#
# ('Learning rate:', 6.500000000000001e-05, 'Regularization strength:', 25000.0)
# ('val_acc:', 0.27500000000000002)
# ('results[learn_rate, reg]', (0.26657142857142857, 0.27500000000000002))
#
# ('Learning rate:', 6.500000000000001e-05, 'Regularization strength:', 35000.0)
# ('val_acc:', 0.28899999999999998)
# ('results[learn_rate, reg]', (0.28442857142857142, 0.28899999999999998))
#
# ('Learning rate:', 6.500000000000001e-05, 'Regularization strength:', 65000.0)
# ('val_acc:', 0.27700000000000002)
# ('results[learn_rate, reg]', (0.26975510204081632, 0.27700000000000002))
#
# ('Learning rate:', 6.500000000000001e-05, 'Regularization strength:', 75000.0)
# ('val_acc:', 0.32800000000000001)
# ('results[learn_rate, reg]', (0.32869387755102042, 0.32800000000000001))
#
# ('Learning rate:', 7.500000000000001e-05, 'Regularization strength:', 25000.0)
# ('val_acc:', 0.28299999999999997)
# ('results[learn_rate, reg]', (0.27002040816326528, 0.28299999999999997))
#
# ('Learning rate:', 7.500000000000001e-05, 'Regularization strength:', 35000.0)
# ('val_acc:', 0.28599999999999998)
# ('results[learn_rate, reg]', (0.27069387755102042, 0.28599999999999998))
#
# ('Learning rate:', 7.500000000000001e-05, 'Regularization strength:', 65000.0)
# ('val_acc:', 0.247)
# ('results[learn_rate, reg]', (0.26620408163265308, 0.247))
#
# ('Learning rate:', 7.500000000000001e-05, 'Regularization strength:', 75000.0)
# ('val_acc:', 0.30499999999999999)
# ('results[learn_rate, reg]', (0.31442857142857145, 0.30499999999999999))
#
# ('Loop', 2)
# ('Learning rates:', [3.2500000000000004e-05, 4.550000000000001e-05, 8.450000000000001e-05, 9.750000000000001e-05])
# ('Regularization strenghts:', [37500.0, 52500.0, 97500.0, 112500.0])
# ('Learning rate:', 3.2500000000000004e-05, 'Regularization strength:', 37500.0)
# ('val_acc:', 0.29199999999999998)
# ('results[learn_rate, reg]', (0.28291836734693876, 0.29199999999999998))
#
# ('Learning rate:', 3.2500000000000004e-05, 'Regularization strength:', 52500.0)
# ('val_acc:', 0.312)
# ('results[learn_rate, reg]', (0.29110204081632651, 0.312))
#
# ('Learning rate:', 3.2500000000000004e-05, 'Regularization strength:', 97500.0)
# ('val_acc:', 0.247)
# ('results[learn_rate, reg]', (0.24465306122448979, 0.247))
#
# ('Learning rate:', 3.2500000000000004e-05, 'Regularization strength:', 112500.0)
# ('val_acc:', 0.313)
# ('results[learn_rate, reg]', (0.30191836734693878, 0.313))
#
# ('Learning rate:', 4.550000000000001e-05, 'Regularization strength:', 37500.0)
# ('val_acc:', 0.313)
# ('results[learn_rate, reg]', (0.31095918367346936, 0.313))
#
# ('Learning rate:', 4.550000000000001e-05, 'Regularization strength:', 52500.0)
# ('val_acc:', 0.317)
# ('results[learn_rate, reg]', (0.31179591836734694, 0.317))
#
# ('Learning rate:', 4.550000000000001e-05, 'Regularization strength:', 97500.0)
# ('val_acc:', 0.27500000000000002)
# ('results[learn_rate, reg]', (0.2634285714285714, 0.27500000000000002))
#
# ('Learning rate:', 4.550000000000001e-05, 'Regularization strength:', 112500.0)
# ('val_acc:', 0.316)
# ('results[learn_rate, reg]', (0.2890204081632653, 0.316))
#
# ('Learning rate:', 8.450000000000001e-05, 'Regularization strength:', 37500.0)
# ('val_acc:', 0.27200000000000002)
# ('results[learn_rate, reg]', (0.27391836734693875, 0.27200000000000002))
#
# ('Learning rate:', 8.450000000000001e-05, 'Regularization strength:', 52500.0)
# ('val_acc:', 0.28999999999999998)
# ('results[learn_rate, reg]', (0.29714285714285715, 0.28999999999999998))
#
# ('Learning rate:', 8.450000000000001e-05, 'Regularization strength:', 97500.0)
# ('val_acc:', 0.26600000000000001)
# ('results[learn_rate, reg]', (0.26959183673469389, 0.26600000000000001))
#
# ('Learning rate:', 8.450000000000001e-05, 'Regularization strength:', 112500.0)
# ('val_acc:', 0.30299999999999999)
# ('results[learn_rate, reg]', (0.28828571428571431, 0.30299999999999999))
#
# ('Learning rate:', 9.750000000000001e-05, 'Regularization strength:', 37500.0)
# ('val_acc:', 0.32100000000000001)
# ('results[learn_rate, reg]', (0.28897959183673472, 0.32100000000000001))
#
# ('Learning rate:', 9.750000000000001e-05, 'Regularization strength:', 52500.0)
# ('val_acc:', 0.27200000000000002)
# ('results[learn_rate, reg]', (0.28526530612244899, 0.27200000000000002))
#
# ('Learning rate:', 9.750000000000001e-05, 'Regularization strength:', 97500.0)
# ('val_acc:', 0.27500000000000002)
# ('results[learn_rate, reg]', (0.25981632653061226, 0.27500000000000002))
#
# ('Learning rate:', 9.750000000000001e-05, 'Regularization strength:', 112500.0)
# ('val_acc:', 0.26400000000000001)
# ('results[learn_rate, reg]', (0.26075510204081631, 0.26400000000000001))
#
# ('Loop', 3)
# ('Learning rates:', [3.2500000000000004e-05, 4.550000000000001e-05, 8.450000000000001e-05, 9.750000000000001e-05])
# ('Regularization strenghts:', [37500.0, 52500.0, 97500.0, 112500.0])
# ('Learning rate:', 3.2500000000000004e-05, 'Regularization strength:', 37500.0)
# ('val_acc:', 0.315)
# ('results[learn_rate, reg]', (0.30059183673469386, 0.315))
#
# ('Learning rate:', 3.2500000000000004e-05, 'Regularization strength:', 52500.0)
# ('val_acc:', 0.26300000000000001)
# ('results[learn_rate, reg]', (0.29330612244897958, 0.26300000000000001))
#
# ('Learning rate:', 3.2500000000000004e-05, 'Regularization strength:', 97500.0)
# ('val_acc:', 0.29799999999999999)
# ('results[learn_rate, reg]', (0.2845918367346939, 0.29799999999999999))
#
# ('Learning rate:', 3.2500000000000004e-05, 'Regularization strength:', 112500.0)
# ('val_acc:', 0.30499999999999999)
# ('results[learn_rate, reg]', (0.29773469387755103, 0.30499999999999999))
#
# ('Learning rate:', 4.550000000000001e-05, 'Regularization strength:', 37500.0)
# ('val_acc:', 0.317)
# ('results[learn_rate, reg]', (0.29455102040816328, 0.317))
#
# ('Learning rate:', 4.550000000000001e-05, 'Regularization strength:', 52500.0)
# ('val_acc:', 0.23200000000000001)
# ('results[learn_rate, reg]', (0.23579591836734695, 0.23200000000000001))
#
# ('Learning rate:', 4.550000000000001e-05, 'Regularization strength:', 97500.0)
# ('val_acc:', 0.307)
# ('results[learn_rate, reg]', (0.29269387755102039, 0.307))
#
# ('Learning rate:', 4.550000000000001e-05, 'Regularization strength:', 112500.0)
# ('val_acc:', 0.26200000000000001)
# ('results[learn_rate, reg]', (0.27789795918367349, 0.26200000000000001))
#
# ('Learning rate:', 8.450000000000001e-05, 'Regularization strength:', 37500.0)
# ('val_acc:', 0.27400000000000002)
# ('results[learn_rate, reg]', (0.26738775510204082, 0.27400000000000002))
#
# ('Learning rate:', 8.450000000000001e-05, 'Regularization strength:', 52500.0)
# ('val_acc:', 0.30199999999999999)
# ('results[learn_rate, reg]', (0.28873469387755102, 0.30199999999999999))
#
# ('Learning rate:', 8.450000000000001e-05, 'Regularization strength:', 97500.0)
# ('val_acc:', 0.307)
# ('results[learn_rate, reg]', (0.32075510204081631, 0.307))
#
# ('Learning rate:', 8.450000000000001e-05, 'Regularization strength:', 112500.0)
# ('val_acc:', 0.26900000000000002)
# ('results[learn_rate, reg]', (0.26146938775510203, 0.26900000000000002))
#
# ('Learning rate:', 9.750000000000001e-05, 'Regularization strength:', 37500.0)
# ('val_acc:', 0.29699999999999999)
# ('results[learn_rate, reg]', (0.27248979591836736, 0.29699999999999999))
#
# ('Learning rate:', 9.750000000000001e-05, 'Regularization strength:', 52500.0)
# ('val_acc:', 0.27200000000000002)
# ('results[learn_rate, reg]', (0.2664285714285714, 0.27200000000000002))
#
# ('Learning rate:', 9.750000000000001e-05, 'Regularization strength:', 97500.0)
# ('val_acc:', 0.28299999999999997)
# ('results[learn_rate, reg]', (0.26887755102040817, 0.28299999999999997))
#
# ('Learning rate:', 9.750000000000001e-05, 'Regularization strength:', 112500.0)
# ('val_acc:', 0.29099999999999998)
# ('results[learn_rate, reg]', (0.27797959183673471, 0.29099999999999998))
#
# ('Loop', 4)
# ('Learning rates:', [3.2500000000000004e-05, 4.550000000000001e-05, 8.450000000000001e-05, 9.750000000000001e-05])
# ('Regularization strenghts:', [37500.0, 52500.0, 97500.0, 112500.0])
# ('Learning rate:', 3.2500000000000004e-05, 'Regularization strength:', 37500.0)
# ('val_acc:', 0.20899999999999999)
# ('results[learn_rate, reg]', (0.24451020408163265, 0.20899999999999999))
#
# ('Learning rate:', 3.2500000000000004e-05, 'Regularization strength:', 52500.0)
# ('val_acc:', 0.26800000000000002)
# ('results[learn_rate, reg]', (0.27861224489795916, 0.26800000000000002))
#
# ('Learning rate:', 3.2500000000000004e-05, 'Regularization strength:', 97500.0)
# ('val_acc:', 0.26800000000000002)
# ('results[learn_rate, reg]', (0.26738775510204082, 0.26800000000000002))
#
# ('Learning rate:', 3.2500000000000004e-05, 'Regularization strength:', 112500.0)
# ('val_acc:', 0.28599999999999998)
# ('results[learn_rate, reg]', (0.29246938775510206, 0.28599999999999998))
#
# ('Learning rate:', 4.550000000000001e-05, 'Regularization strength:', 37500.0)
# ('val_acc:', 0.33600000000000002)
# ('results[learn_rate, reg]', (0.33263265306122447, 0.33600000000000002))
#
# ('Learning rate:', 4.550000000000001e-05, 'Regularization strength:', 52500.0)
# ('val_acc:', 0.29999999999999999)
# ('results[learn_rate, reg]', (0.28869387755102038, 0.29999999999999999))
#
# ('Learning rate:', 4.550000000000001e-05, 'Regularization strength:', 97500.0)
# ('val_acc:', 0.29099999999999998)
# ('results[learn_rate, reg]', (0.27522448979591835, 0.29099999999999998))
#
# ('Learning rate:', 4.550000000000001e-05, 'Regularization strength:', 112500.0)
# ('val_acc:', 0.27900000000000003)
# ('results[learn_rate, reg]', (0.28848979591836732, 0.27900000000000003))
#
# ('Learning rate:', 8.450000000000001e-05, 'Regularization strength:', 37500.0)
# ('val_acc:', 0.24399999999999999)
# ('results[learn_rate, reg]', (0.25008163265306121, 0.24399999999999999))
#
# ('Learning rate:', 8.450000000000001e-05, 'Regularization strength:', 52500.0)
# ('val_acc:', 0.27900000000000003)
# ('results[learn_rate, reg]', (0.26526530612244897, 0.27900000000000003))
#
# ('Learning rate:', 8.450000000000001e-05, 'Regularization strength:', 97500.0)
# ('val_acc:', 0.27400000000000002)
# ('results[learn_rate, reg]', (0.28955102040816327, 0.27400000000000002))
#
# ('Learning rate:', 8.450000000000001e-05, 'Regularization strength:', 112500.0)
# ('val_acc:', 0.26100000000000001)
# ('results[learn_rate, reg]', (0.26630612244897961, 0.26100000000000001))
#
# ('Learning rate:', 9.750000000000001e-05, 'Regularization strength:', 37500.0)
# ('val_acc:', 0.27200000000000002)
# ('results[learn_rate, reg]', (0.26326530612244897, 0.27200000000000002))
#
# ('Learning rate:', 9.750000000000001e-05, 'Regularization strength:', 52500.0)
# ('val_acc:', 0.29599999999999999)
# ('results[learn_rate, reg]', (0.27912244897959182, 0.29599999999999999))
#
# ('Learning rate:', 9.750000000000001e-05, 'Regularization strength:', 97500.0)
# ('val_acc:', 0.25800000000000001)
# ('results[learn_rate, reg]', (0.25036734693877549, 0.25800000000000001))
#
# ('Learning rate:', 9.750000000000001e-05, 'Regularization strength:', 112500.0)
# ('val_acc:', 0.29799999999999999)
# ('results[learn_rate, reg]', (0.29165306122448981, 0.29799999999999999))
#
# ('Loop', 5)
# ('Learning rates:', [2.2750000000000004e-05, 3.185000000000001e-05, 5.915000000000001e-05, 6.825e-05])
# ('Regularization strenghts:', [18750.0, 26250.0, 48750.0, 56250.0])
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.28100000000000003)
# ('results[learn_rate, reg]', (0.28475510204081633, 0.28100000000000003))
#
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.30199999999999999)
# ('results[learn_rate, reg]', (0.29810204081632652, 0.30199999999999999))
#
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.26100000000000001)
# ('results[learn_rate, reg]', (0.27159183673469389, 0.26100000000000001))
#
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.27700000000000002)
# ('results[learn_rate, reg]', (0.26212244897959186, 0.27700000000000002))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.29599999999999999)
# ('results[learn_rate, reg]', (0.30044897959183675, 0.29599999999999999))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.28399999999999997)
# ('results[learn_rate, reg]', (0.28536734693877552, 0.28399999999999997))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.29299999999999998)
# ('results[learn_rate, reg]', (0.30155102040816328, 0.29299999999999998))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.25)
# ('results[learn_rate, reg]', (0.25410204081632654, 0.25))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.29099999999999998)
# ('results[learn_rate, reg]', (0.27420408163265308, 0.29099999999999998))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.29599999999999999)
# ('results[learn_rate, reg]', (0.28512244897959182, 0.29599999999999999))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.27700000000000002)
# ('results[learn_rate, reg]', (0.25885714285714284, 0.27700000000000002))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.28299999999999997)
# ('results[learn_rate, reg]', (0.29265306122448981, 0.28299999999999997))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.30499999999999999)
# ('results[learn_rate, reg]', (0.29310204081632651, 0.30499999999999999))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.29999999999999999)
# ('results[learn_rate, reg]', (0.28232653061224489, 0.29999999999999999))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.25600000000000001)
# ('results[learn_rate, reg]', (0.26218367346938776, 0.25600000000000001))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.26300000000000001)
# ('results[learn_rate, reg]', (0.25277551020408162, 0.26300000000000001))
#
# ('Loop', 6)
# ('Learning rates:', [2.2750000000000004e-05, 3.185000000000001e-05, 5.915000000000001e-05, 6.825e-05])
# ('Regularization strenghts:', [18750.0, 26250.0, 48750.0, 56250.0])
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.27800000000000002)
# ('results[learn_rate, reg]', (0.2646122448979592, 0.27800000000000002))
#
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.29799999999999999)
# ('results[learn_rate, reg]', (0.28861224489795917, 0.29799999999999999))
#
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.30399999999999999)
# ('results[learn_rate, reg]', (0.29622448979591837, 0.30399999999999999))
#
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.27700000000000002)
# ('results[learn_rate, reg]', (0.25508163265306122, 0.27700000000000002))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.25600000000000001)
# ('results[learn_rate, reg]', (0.25383673469387757, 0.25600000000000001))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.28999999999999998)
# ('results[learn_rate, reg]', (0.27206122448979592, 0.28999999999999998))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.29399999999999998)
# ('results[learn_rate, reg]', (0.30648979591836734, 0.29399999999999998))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.312)
# ('results[learn_rate, reg]', (0.29269387755102039, 0.312))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.27100000000000002)
# ('results[learn_rate, reg]', (0.26385714285714285, 0.27100000000000002))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.29899999999999999)
# ('results[learn_rate, reg]', (0.2877142857142857, 0.29899999999999999))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.26900000000000002)
# ('results[learn_rate, reg]', (0.26908163265306123, 0.26900000000000002))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.23300000000000001)
# ('results[learn_rate, reg]', (0.24551020408163265, 0.23300000000000001))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.33000000000000002)
# ('results[learn_rate, reg]', (0.31071428571428572, 0.33000000000000002))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.27400000000000002)
# ('results[learn_rate, reg]', (0.26859183673469389, 0.27400000000000002))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.28399999999999997)
# ('results[learn_rate, reg]', (0.27793877551020407, 0.28399999999999997))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.27700000000000002)
# ('results[learn_rate, reg]', (0.2729795918367347, 0.27700000000000002))
#
# ('Loop', 7)
# ('Learning rates:', [2.2750000000000004e-05, 3.185000000000001e-05, 5.915000000000001e-05, 6.825e-05])
# ('Regularization strenghts:', [18750.0, 26250.0, 48750.0, 56250.0])
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.312)
# ('results[learn_rate, reg]', (0.30646938775510202, 0.312))
#
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.32600000000000001)
# ('results[learn_rate, reg]', (0.30957142857142855, 0.32600000000000001))
#
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.30499999999999999)
# ('results[learn_rate, reg]', (0.29842857142857143, 0.30499999999999999))
#
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.30299999999999999)
# ('results[learn_rate, reg]', (0.29514285714285715, 0.30299999999999999))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.29099999999999998)
# ('results[learn_rate, reg]', (0.29324489795918368, 0.29099999999999998))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.23200000000000001)
# ('results[learn_rate, reg]', (0.23440816326530611, 0.23200000000000001))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.27600000000000002)
# ('results[learn_rate, reg]', (0.27977551020408165, 0.27600000000000002))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.29499999999999998)
# ('results[learn_rate, reg]', (0.29130612244897958, 0.29499999999999998))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.30199999999999999)
# ('results[learn_rate, reg]', (0.31518367346938775, 0.30199999999999999))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.29799999999999999)
# ('results[learn_rate, reg]', (0.30159183673469386, 0.29799999999999999))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.27300000000000002)
# ('results[learn_rate, reg]', (0.26965306122448979, 0.27300000000000002))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.30099999999999999)
# ('results[learn_rate, reg]', (0.29297959183673472, 0.30099999999999999))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.29499999999999998)
# ('results[learn_rate, reg]', (0.2940204081632653, 0.29499999999999998))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.248)
# ('results[learn_rate, reg]', (0.27010204081632655, 0.248))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.28399999999999997)
# ('results[learn_rate, reg]', (0.26940816326530614, 0.28399999999999997))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.24299999999999999)
# ('results[learn_rate, reg]', (0.2613673469387755, 0.24299999999999999))
#
# ('Loop', 8)
# ('Learning rates:', [2.2750000000000004e-05, 3.185000000000001e-05, 5.915000000000001e-05, 6.825e-05])
# ('Regularization strenghts:', [18750.0, 26250.0, 48750.0, 56250.0])
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.28599999999999998)
# ('results[learn_rate, reg]', (0.30777551020408161, 0.28599999999999998))
#
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.25900000000000001)
# ('results[learn_rate, reg]', (0.25667346938775509, 0.25900000000000001))
#
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.29199999999999998)
# ('results[learn_rate, reg]', (0.2876530612244898, 0.29199999999999998))
#
# ('Learning rate:', 2.2750000000000004e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.309)
# ('results[learn_rate, reg]', (0.29397959183673472, 0.309))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.29699999999999999)
# ('results[learn_rate, reg]', (0.27602040816326529, 0.29699999999999999))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.24199999999999999)
# ('results[learn_rate, reg]', (0.25012244897959185, 0.24199999999999999))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.28699999999999998)
# ('results[learn_rate, reg]', (0.29544897959183675, 0.28699999999999998))
#
# ('Learning rate:', 3.185000000000001e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.27400000000000002)
# ('results[learn_rate, reg]', (0.26681632653061227, 0.27400000000000002))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.25900000000000001)
# ('results[learn_rate, reg]', (0.2686734693877551, 0.25900000000000001))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.26900000000000002)
# ('results[learn_rate, reg]', (0.26934693877551019, 0.26900000000000002))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.33700000000000002)
# ('results[learn_rate, reg]', (0.32975510204081632, 0.33700000000000002))
#
# ('Learning rate:', 5.915000000000001e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.29399999999999998)
# ('results[learn_rate, reg]', (0.31481632653061226, 0.29399999999999998))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 18750.0)
# ('val_acc:', 0.26600000000000001)
# ('results[learn_rate, reg]', (0.27451020408163268, 0.26600000000000001))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 26250.0)
# ('val_acc:', 0.317)
# ('results[learn_rate, reg]', (0.31697959183673469, 0.317))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 48750.0)
# ('val_acc:', 0.29699999999999999)
# ('results[learn_rate, reg]', (0.28851020408163264, 0.29699999999999999))
#
# ('Learning rate:', 6.825e-05, 'Regularization strength:', 56250.0)
# ('val_acc:', 0.26800000000000002)
# ('results[learn_rate, reg]', (0.26730612244897961, 0.26800000000000002))
#
# ('Loop', 9)
# ('Learning rates:', [2.9575000000000004e-05, 4.140500000000001e-05, 7.6895e-05, 8.872500000000002e-05])
# ('Regularization strenghts:', [24375.0, 34125.0, 63375.0, 73125.0])
# ('Learning rate:', 2.9575000000000004e-05, 'Regularization strength:', 24375.0)
# ('val_acc:', 0.254)
# ('results[learn_rate, reg]', (0.26818367346938776, 0.254))
#
# ('Learning rate:', 2.9575000000000004e-05, 'Regularization strength:', 34125.0)
# ('val_acc:', 0.311)
# ('results[learn_rate, reg]', (0.29242857142857143, 0.311))
#
# ('Learning rate:', 2.9575000000000004e-05, 'Regularization strength:', 63375.0)
# ('val_acc:', 0.26000000000000001)
# ('results[learn_rate, reg]', (0.2802857142857143, 0.26000000000000001))
#
# ('Learning rate:', 2.9575000000000004e-05, 'Regularization strength:', 73125.0)
# ('val_acc:', 0.27300000000000002)
# ('results[learn_rate, reg]', (0.28473469387755102, 0.27300000000000002))
#
# ('Learning rate:', 4.140500000000001e-05, 'Regularization strength:', 24375.0)
# ('val_acc:', 0.30399999999999999)
# ('results[learn_rate, reg]', (0.29136734693877553, 0.30399999999999999))
#
# ('Learning rate:', 4.140500000000001e-05, 'Regularization strength:', 34125.0)
# ('val_acc:', 0.26900000000000002)
# ('results[learn_rate, reg]', (0.24048979591836736, 0.26900000000000002))
#
# ('Learning rate:', 4.140500000000001e-05, 'Regularization strength:', 63375.0)
# ('val_acc:', 0.26500000000000001)
# ('results[learn_rate, reg]', (0.24895918367346939, 0.26500000000000001))
#
# ('Learning rate:', 4.140500000000001e-05, 'Regularization strength:', 73125.0)
# ('val_acc:', 0.29599999999999999)
# ('results[learn_rate, reg]', (0.29853061224489796, 0.29599999999999999))
#
# ('Learning rate:', 7.6895e-05, 'Regularization strength:', 24375.0)
# ('val_acc:', 0.27400000000000002)
# ('results[learn_rate, reg]', (0.28338775510204084, 0.27400000000000002))
#
# ('Learning rate:', 7.6895e-05, 'Regularization strength:', 34125.0)
# ('val_acc:', 0.24199999999999999)
# ('results[learn_rate, reg]', (0.24167346938775511, 0.24199999999999999))
#
# ('Learning rate:', 7.6895e-05, 'Regularization strength:', 63375.0)
# ('val_acc:', 0.32000000000000001)
# ('results[learn_rate, reg]', (0.3147551020408163, 0.32000000000000001))
#
# ('Learning rate:', 7.6895e-05, 'Regularization strength:', 73125.0)
# ('val_acc:', 0.28299999999999997)
# ('results[learn_rate, reg]', (0.28067346938775511, 0.28299999999999997))
#
# ('Learning rate:', 8.872500000000002e-05, 'Regularization strength:', 24375.0)
# ('val_acc:', 0.27400000000000002)
# ('results[learn_rate, reg]', (0.26877551020408164, 0.27400000000000002))
#
# ('Learning rate:', 8.872500000000002e-05, 'Regularization strength:', 34125.0)
# ('val_acc:', 0.28599999999999998)
# ('results[learn_rate, reg]', (0.28955102040816327, 0.28599999999999998))
#
# ('Learning rate:', 8.872500000000002e-05, 'Regularization strength:', 63375.0)
# ('val_acc:', 0.26700000000000002)
# ('results[learn_rate, reg]', (0.25348979591836734, 0.26700000000000002))
#
# ('Learning rate:', 8.872500000000002e-05, 'Regularization strength:', 73125.0)
# ('val_acc:', 0.311)
# ('results[learn_rate, reg]', (0.30502040816326531, 0.311))
#
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.217265 val accuracy: 0.216000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.217184 val accuracy: 0.253000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.218286 val accuracy: 0.226000
# lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.284673 val accuracy: 0.293000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.273000 val accuracy: 0.279000
# lr 5.000000e-07 reg 1.000000e+05 train accuracy: 0.275122 val accuracy: 0.268000
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.301673 val accuracy: 0.304000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.302551 val accuracy: 0.310000
# lr 1.000000e-06 reg 1.000000e+05 train accuracy: 0.304694 val accuracy: 0.312000
# lr 5.000000e-06 reg 1.000000e+04 train accuracy: 0.293959 val accuracy: 0.307000
# lr 5.000000e-06 reg 5.000000e+04 train accuracy: 0.251347 val accuracy: 0.268000
# lr 5.000000e-06 reg 1.000000e+05 train accuracy: 0.279061 val accuracy: 0.296000
# lr 1.000000e-05 reg 1.000000e+04 train accuracy: 0.273388 val accuracy: 0.264000
# lr 1.000000e-05 reg 5.000000e+04 train accuracy: 0.268755 val accuracy: 0.278000
# lr 1.000000e-05 reg 1.000000e+05 train accuracy: 0.278898 val accuracy: 0.299000
# lr 2.275000e-05 reg 1.875000e+04 train accuracy: 0.307776 val accuracy: 0.286000
# lr 2.275000e-05 reg 2.625000e+04 train accuracy: 0.256673 val accuracy: 0.259000
# lr 2.275000e-05 reg 4.875000e+04 train accuracy: 0.287653 val accuracy: 0.292000
# lr 2.275000e-05 reg 5.625000e+04 train accuracy: 0.293980 val accuracy: 0.309000
# lr 2.500000e-05 reg 2.500000e+04 train accuracy: 0.233531 val accuracy: 0.253000
# lr 2.500000e-05 reg 3.500000e+04 train accuracy: 0.230429 val accuracy: 0.236000
# lr 2.500000e-05 reg 6.500000e+04 train accuracy: 0.297143 val accuracy: 0.275000
# lr 2.500000e-05 reg 7.500000e+04 train accuracy: 0.298265 val accuracy: 0.280000
# lr 2.957500e-05 reg 2.437500e+04 train accuracy: 0.268184 val accuracy: 0.254000
# lr 2.957500e-05 reg 3.412500e+04 train accuracy: 0.292429 val accuracy: 0.311000
# lr 2.957500e-05 reg 6.337500e+04 train accuracy: 0.280286 val accuracy: 0.260000
# lr 2.957500e-05 reg 7.312500e+04 train accuracy: 0.284735 val accuracy: 0.273000
# lr 3.185000e-05 reg 1.875000e+04 train accuracy: 0.276020 val accuracy: 0.297000
# lr 3.185000e-05 reg 2.625000e+04 train accuracy: 0.250122 val accuracy: 0.242000
# lr 3.185000e-05 reg 4.875000e+04 train accuracy: 0.295449 val accuracy: 0.287000
# lr 3.185000e-05 reg 5.625000e+04 train accuracy: 0.266816 val accuracy: 0.274000
# lr 3.250000e-05 reg 3.750000e+04 train accuracy: 0.244510 val accuracy: 0.209000
# lr 3.250000e-05 reg 5.250000e+04 train accuracy: 0.278612 val accuracy: 0.268000
# lr 3.250000e-05 reg 9.750000e+04 train accuracy: 0.267388 val accuracy: 0.268000
# lr 3.250000e-05 reg 1.125000e+05 train accuracy: 0.292469 val accuracy: 0.286000
# lr 3.500000e-05 reg 2.500000e+04 train accuracy: 0.258224 val accuracy: 0.279000
# lr 3.500000e-05 reg 3.500000e+04 train accuracy: 0.307980 val accuracy: 0.295000
# lr 3.500000e-05 reg 6.500000e+04 train accuracy: 0.251000 val accuracy: 0.249000
# lr 3.500000e-05 reg 7.500000e+04 train accuracy: 0.293755 val accuracy: 0.304000
# lr 4.140500e-05 reg 2.437500e+04 train accuracy: 0.291367 val accuracy: 0.304000
# lr 4.140500e-05 reg 3.412500e+04 train accuracy: 0.240490 val accuracy: 0.269000
# lr 4.140500e-05 reg 6.337500e+04 train accuracy: 0.248959 val accuracy: 0.265000
# lr 4.140500e-05 reg 7.312500e+04 train accuracy: 0.298531 val accuracy: 0.296000
# lr 4.550000e-05 reg 3.750000e+04 train accuracy: 0.332633 val accuracy: 0.336000
# lr 4.550000e-05 reg 5.250000e+04 train accuracy: 0.288694 val accuracy: 0.300000
# lr 4.550000e-05 reg 9.750000e+04 train accuracy: 0.275224 val accuracy: 0.291000
# lr 4.550000e-05 reg 1.125000e+05 train accuracy: 0.288490 val accuracy: 0.279000
# lr 5.000000e-05 reg 1.000000e+04 train accuracy: 0.282122 val accuracy: 0.278000
# lr 5.000000e-05 reg 5.000000e+04 train accuracy: 0.297857 val accuracy: 0.316000
# lr 5.000000e-05 reg 1.000000e+05 train accuracy: 0.290633 val accuracy: 0.297000
# lr 5.915000e-05 reg 1.875000e+04 train accuracy: 0.268673 val accuracy: 0.259000
# lr 5.915000e-05 reg 2.625000e+04 train accuracy: 0.269347 val accuracy: 0.269000
# lr 5.915000e-05 reg 4.875000e+04 train accuracy: 0.329755 val accuracy: 0.337000
# lr 5.915000e-05 reg 5.625000e+04 train accuracy: 0.314816 val accuracy: 0.294000
# lr 6.500000e-05 reg 2.500000e+04 train accuracy: 0.266571 val accuracy: 0.275000
# lr 6.500000e-05 reg 3.500000e+04 train accuracy: 0.284429 val accuracy: 0.289000
# lr 6.500000e-05 reg 6.500000e+04 train accuracy: 0.269755 val accuracy: 0.277000
# lr 6.500000e-05 reg 7.500000e+04 train accuracy: 0.328694 val accuracy: 0.328000
# lr 6.825000e-05 reg 1.875000e+04 train accuracy: 0.274510 val accuracy: 0.266000
# lr 6.825000e-05 reg 2.625000e+04 train accuracy: 0.316980 val accuracy: 0.317000
# lr 6.825000e-05 reg 4.875000e+04 train accuracy: 0.288510 val accuracy: 0.297000
# lr 6.825000e-05 reg 5.625000e+04 train accuracy: 0.267306 val accuracy: 0.268000
# lr 7.500000e-05 reg 2.500000e+04 train accuracy: 0.270020 val accuracy: 0.283000
# lr 7.500000e-05 reg 3.500000e+04 train accuracy: 0.270694 val accuracy: 0.286000
# lr 7.500000e-05 reg 6.500000e+04 train accuracy: 0.266204 val accuracy: 0.247000
# lr 7.500000e-05 reg 7.500000e+04 train accuracy: 0.314429 val accuracy: 0.305000
# lr 7.689500e-05 reg 2.437500e+04 train accuracy: 0.283388 val accuracy: 0.274000
# lr 7.689500e-05 reg 3.412500e+04 train accuracy: 0.241673 val accuracy: 0.242000
# lr 7.689500e-05 reg 6.337500e+04 train accuracy: 0.314755 val accuracy: 0.320000
# lr 7.689500e-05 reg 7.312500e+04 train accuracy: 0.280673 val accuracy: 0.283000
# lr 8.450000e-05 reg 3.750000e+04 train accuracy: 0.250082 val accuracy: 0.244000
# lr 8.450000e-05 reg 5.250000e+04 train accuracy: 0.265265 val accuracy: 0.279000
# lr 8.450000e-05 reg 9.750000e+04 train accuracy: 0.289551 val accuracy: 0.274000
# lr 8.450000e-05 reg 1.125000e+05 train accuracy: 0.266306 val accuracy: 0.261000
# lr 8.872500e-05 reg 2.437500e+04 train accuracy: 0.268776 val accuracy: 0.274000
# lr 8.872500e-05 reg 3.412500e+04 train accuracy: 0.289551 val accuracy: 0.286000
# lr 8.872500e-05 reg 6.337500e+04 train accuracy: 0.253490 val accuracy: 0.267000
# lr 8.872500e-05 reg 7.312500e+04 train accuracy: 0.305020 val accuracy: 0.311000
# lr 9.750000e-05 reg 3.750000e+04 train accuracy: 0.263265 val accuracy: 0.272000
# lr 9.750000e-05 reg 5.250000e+04 train accuracy: 0.279122 val accuracy: 0.296000
# lr 9.750000e-05 reg 9.750000e+04 train accuracy: 0.250367 val accuracy: 0.258000
# lr 9.750000e-05 reg 1.125000e+05 train accuracy: 0.291653 val accuracy: 0.298000
# best validation accuracy achieved during cross-validation: 0.337000

# %%
# Visualize the cross-validation results
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
# Evaluate the best svm on test set
y_test_pred = best_svm.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print 'linear SVM on raw pixels final test set accuracy: %f' % test_accuracy

# %%
# Visualize the learned weights for each class.
# Depending on your choice of learning rate and regularization strength, these may
# or may not be nice to look at.
w = best_svm.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)
w_min, w_max = np.min(w), np.max(w)
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
    
  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])

# %% [markdown]
# ### Inline question 2:
# Describe what your visualized SVM weights look like, and offer a brief explanation for why they look they way that they do.
#
# **Your answer:** *fill this in*
