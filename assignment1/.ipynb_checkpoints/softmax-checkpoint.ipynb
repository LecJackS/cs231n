# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
  """
  Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
  it for the linear classifier. These are the same steps as we used for the
  SVM, but condensed to a single function.  
  """
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]
  mask = np.random.choice(num_training, num_dev, replace=False)
  X_dev = X_train[mask]
  y_dev = y_train[mask]
  
  # Preprocessing: reshape the image data into rows
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))
  X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
  
  # Normalize the data: subtract the mean image
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_dev -= mean_image
  
  # add bias dimension and transform into columns
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
  X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
  
  return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
print 'dev data shape: ', X_dev.shape
print 'dev labels shape: ', y_dev.shape
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.00)

# As a rough sanity check, our loss should be something close to -log(0.1).
print 'loss: %f' % loss
print 'sanity check: %f' % (-np.log(0.1))
# Out:
# loss: 2.332252
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*
#
# There are ten classes, and the classifier is not trained yet, so, 1/10 probability on the correct example.

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

print("")

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 1e2)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.809907 analytic: -0.809907, relative error: 1.830570e-08
# numerical: 0.957424 analytic: 0.957424, relative error: 6.167041e-09
# numerical: 0.387605 analytic: 0.387605, relative error: 4.568112e-08
# numerical: -1.925557 analytic: -1.925557, relative error: 1.552916e-08
# numerical: 0.023159 analytic: 0.023159, relative error: 6.103354e-07
# numerical: -2.972609 analytic: -2.972609, relative error: 3.507628e-09
# numerical: -2.235871 analytic: -2.235870, relative error: 3.584455e-09
# numerical: -0.916242 analytic: -0.916242, relative error: 1.857842e-08
# numerical: 2.035062 analytic: 2.035062, relative error: 1.752880e-09
# numerical: -0.767439 analytic: -0.767439, relative error: 2.557064e-08
#
# numerical: 0.790470 analytic: 0.790470, relative error: 6.631237e-08
# numerical: 0.629189 analytic: 0.629189, relative error: 7.354327e-08
# numerical: -2.932280 analytic: -2.932281, relative error: 9.562976e-10
# numerical: 0.037749 analytic: 0.037749, relative error: 1.217511e-07
# numerical: 2.230088 analytic: 2.230087, relative error: 1.648140e-08
# numerical: -1.252552 analytic: -1.252553, relative error: 1.769145e-08
# numerical: 0.633889 analytic: 0.633889, relative error: 8.920409e-08
# numerical: 1.208485 analytic: 1.208485, relative error: 3.311638e-08
# numerical: 2.128838 analytic: 2.128838, relative error: 4.366809e-08
# numerical: 1.389210 analytic: 1.389210, relative error: 4.664087e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'naive loss: %e computed in %fs' % (loss_naive, toc - tic)

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic)

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print 'Loss difference: %f' % np.abs(loss_naive - loss_vectorized)
print 'Gradient difference: %f' % grad_difference
# Out:
# naive loss: 2.332252e+00 computed in 0.209363s
# vectorized loss: 2.332252e+00 computed in 0.248342s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7, 1e-5, 5e-5, 1e-6, 5e-6]
regularization_strengths = [1e4, 5e4, 1e5]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
best_lr = 0
best_reg = 0
for i in range(10):
    print("Loop", i)
    print("Learning rates:", learning_rates)
    print("Regularization strenghts:",regularization_strengths)
    for learn_rate in learning_rates:
        for reg in regularization_strengths:
            print("Learning rate:", learn_rate, "Regularization strength:", reg)
            softmax = Softmax()
            loss_hist = softmax.train(X_train, y_train, learning_rate=learn_rate, reg=reg,
                          num_iters=150, verbose=True)

            y_train_pred = softmax.predict(X_train)
            y_val_pred = softmax.predict(X_val)

            training_acc = np.mean(y_train == y_train_pred)
            val_acc = np.mean(y_val == y_val_pred)

            results[learn_rate, reg] = training_acc, val_acc

            if val_acc > best_val:
                best_val = val_acc
                best_softmax = softmax
                best_lr = learn_rate
                best_reg = reg

            #print("val_acc:",val_acc)
            print("results[learn_rate, reg]", results[learn_rate, reg])
            print("")
            
    # we refill learning rates and regs with similar values as the best ones from last loop
    # this way we can automate the trial and error hyperparamenter search process
    lr_min_range = best_lr - 0.7*best_lr
    lr_max_range = best_lr + 0.7*best_lr
    reg_min_range = best_reg - 0.7*best_reg
    reg_max_range  = best_reg + 0.7*best_reg
    #learning_rates = [best_lr - 0.7*best_lr, best_lr - 0.3*best_lr, best_lr, best_lr + 0.3*best_lr, best_lr + 0.7*best_lr]
    #regularization_strengths = [best_reg - 0.7*best_reg, best_reg - 0.3*best_reg, best_reg, best_reg + 0.3*best_reg, best_reg + 0.7*best_reg]
    # draw 5 random samples for learning rates and reg strenghts
    learning_rates = np.random.uniform(lr_min_range, lr_max_range, 5)
    regularization_strengths = np.random.uniform(reg_min_range,reg_max_range, 5)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# ('Loop', 0)
# ('Learning rates:', [1e-07, 5e-07, 1e-05, 5e-05, 1e-06, 5e-06])
# ('Regularization strenghts:', [10000.0, 50000.0, 100000.0])
# ('Learning rate:', 1e-07, 'Regularization strength:', 10000.0)
# iteration 0 / 150: loss 157.849347
# iteration 100 / 150: loss 128.581773
# ('results[learn_rate, reg]', (0.16028571428571428, 0.14399999999999999))
#
# ('Learning rate:', 1e-07, 'Regularization strength:', 50000.0)
# iteration 0 / 150: loss 778.474277
# iteration 100 / 150: loss 285.617175
# ('results[learn_rate, reg]', (0.16646938775510203, 0.16700000000000001))
#
# ('Learning rate:', 1e-07, 'Regularization strength:', 100000.0)
# iteration 0 / 150: loss 1560.675074
# iteration 100 / 150: loss 209.996263
# ('results[learn_rate, reg]', (0.19904081632653062, 0.19400000000000001))
#
# ('Learning rate:', 5e-07, 'Regularization strength:', 10000.0)
# iteration 0 / 150: loss 158.580787
# iteration 100 / 150: loss 57.707081
# ('results[learn_rate, reg]', (0.26059183673469388, 0.24299999999999999))
#
# ('Learning rate:', 5e-07, 'Regularization strength:', 50000.0)
# iteration 0 / 150: loss 772.756920
# iteration 100 / 150: loss 6.881939
# ('results[learn_rate, reg]', (0.32528571428571429, 0.32900000000000001))
#
# ('Learning rate:', 5e-07, 'Regularization strength:', 100000.0)
# iteration 0 / 150: loss 1537.347489
# iteration 100 / 150: loss 2.219970
# ('results[learn_rate, reg]', (0.29653061224489796, 0.311))
#
# ('Learning rate:', 1e-05, 'Regularization strength:', 10000.0)
# iteration 0 / 150: loss 158.055933
# iteration 100 / 150: loss 3.579935
# ('results[learn_rate, reg]', (0.23130612244897958, 0.24399999999999999))
#
# ('Learning rate:', 1e-05, 'Regularization strength:', 50000.0)
# iteration 0 / 150: loss 768.534202
# iteration 100 / 150: loss 7.656948
# ('results[learn_rate, reg]', (0.1333673469387755, 0.13))
#
# ('Learning rate:', 1e-05, 'Regularization strength:', 100000.0)
# iteration 0 / 150: loss 1538.814693
# iteration 100 / 150: loss 16.810756
# ('results[learn_rate, reg]', (0.07553061224489796, 0.079000000000000001))
#
# ('Learning rate:', 5e-05, 'Regularization strength:', 10000.0)
# iteration 0 / 150: loss 159.878072
# iteration 100 / 150: loss 35.001006
# ('results[learn_rate, reg]', (0.11983673469387755, 0.115))
#
# ('Learning rate:', 5e-05, 'Regularization strength:', 50000.0)
# iteration 0 / 150: loss 764.812703
# cs231n/classifiers/softmax.py:68: RuntimeWarning: overflow encountered in exp
#   exp_X = np.exp(X)
# cs231n/classifiers/softmax.py:70: RuntimeWarning: invalid value encountered in divide
#   return exp_X / np.sum(exp_X, axis=1, keepdims=True)
# cs231n/classifiers/softmax.py:93: RuntimeWarning: divide by zero encountered in log
#   correct_log_probs = -np.log(probs[range(num_examples), y])
# iteration 100 / 150: loss nan
# ('results[learn_rate, reg]', (0.10026530612244898, 0.086999999999999994))
#
# ('Learning rate:', 5e-05, 'Regularization strength:', 100000.0)
# iteration 0 / 150: loss 1530.268404
# iteration 100 / 150: loss nan
# ('results[learn_rate, reg]', (0.10026530612244898, 0.086999999999999994))
#
# ('Learning rate:', 1e-06, 'Regularization strength:', 10000.0)
# iteration 0 / 150: loss 161.794368
# iteration 100 / 150: loss 22.685095
# ('results[learn_rate, reg]', (0.33038775510204083, 0.33800000000000002))
#
# ('Learning rate:', 1e-06, 'Regularization strength:', 50000.0)
# iteration 0 / 150: loss 765.485417
# iteration 100 / 150: loss 2.091919
# ('results[learn_rate, reg]', (0.31534693877551018, 0.31900000000000001))
#
# ('Learning rate:', 1e-06, 'Regularization strength:', 100000.0)
# iteration 0 / 150: loss 1546.955910
# iteration 100 / 150: loss 2.125232
# ('results[learn_rate, reg]', (0.28661224489795917, 0.29599999999999999))
#
# ('Learning rate:', 5e-06, 'Regularization strength:', 10000.0)
# iteration 0 / 150: loss 161.659947
# iteration 100 / 150: loss 2.006266
# ('results[learn_rate, reg]', (0.2983265306122449, 0.29999999999999999))
#
# ('Learning rate:', 5e-06, 'Regularization strength:', 50000.0)
# iteration 0 / 150: loss 783.797293
# iteration 100 / 150: loss 2.323267
# ('results[learn_rate, reg]', (0.21651020408163266, 0.224))
#
# ('Learning rate:', 5e-06, 'Regularization strength:', 100000.0)
# iteration 0 / 150: loss 1536.161106
# iteration 100 / 150: loss 3.575261
# ('results[learn_rate, reg]', (0.15759183673469387, 0.161))
#
# ('Loop', 1)
# ('Learning rates:', [3e-07, 7e-07, 1e-06, 1.2999999999999998e-06, 1.6999999999999998e-06])
# ('Regularization strenghts:', [3000.0, 7000.0, 10000.0, 13000.0, 17000.0])
# ('Learning rate:', 3e-07, 'Regularization strength:', 3000.0)
# iteration 0 / 150: loss 51.564587
# iteration 100 / 150: loss 41.441231
# ('results[learn_rate, reg]', (0.18463265306122448, 0.20599999999999999))
#
# ('Learning rate:', 3e-07, 'Regularization strength:', 7000.0)
# iteration 0 / 150: loss 111.339983
# iteration 100 / 150: loss 71.847464
# ('results[learn_rate, reg]', (0.21579591836734693, 0.224))
#
# ('Learning rate:', 3e-07, 'Regularization strength:', 10000.0)
# iteration 0 / 150: loss 157.059147
# iteration 100 / 150: loss 85.387327
# ('results[learn_rate, reg]', (0.20718367346938776, 0.217))
#
# ('Learning rate:', 3e-07, 'Regularization strength:', 13000.0)
# iteration 0 / 150: loss 205.825462
# iteration 100 / 150: loss 94.130654
# ('results[learn_rate, reg]', (0.22038775510204081, 0.22700000000000001))
#
# ('Learning rate:', 3e-07, 'Regularization strength:', 17000.0)
# iteration 0 / 150: loss 268.634467
# iteration 100 / 150: loss 96.521209
# ('results[learn_rate, reg]', (0.23165306122448981, 0.24099999999999999))
#
# ('Learning rate:', 7e-07, 'Regularization strength:', 3000.0)
# iteration 0 / 150: loss 51.684012
# iteration 100 / 150: loss 32.560664
# ('results[learn_rate, reg]', (0.23975510204081632, 0.221))
#
# ('Learning rate:', 7e-07, 'Regularization strength:', 7000.0)
# iteration 0 / 150: loss 111.802034
# iteration 100 / 150: loss 41.516867
# ('results[learn_rate, reg]', (0.26832653061224487, 0.27100000000000002))
#
# ('Learning rate:', 7e-07, 'Regularization strength:', 10000.0)
# iteration 0 / 150: loss 158.569000
# iteration 100 / 150: loss 39.254333
# ('results[learn_rate, reg]', (0.28940816326530611, 0.28999999999999998))
#
# ('Learning rate:', 7e-07, 'Regularization strength:', 13000.0)
# iteration 0 / 150: loss 207.445177
# iteration 100 / 150: loss 34.219684
# ('results[learn_rate, reg]', (0.31, 0.30099999999999999))
#
# ('Learning rate:', 7e-07, 'Regularization strength:', 17000.0)
# iteration 0 / 150: loss 265.752525
# iteration 100 / 150: loss 25.633834
# ('results[learn_rate, reg]', (0.32400000000000001, 0.33500000000000002))
#
# ('Learning rate:', 1e-06, 'Regularization strength:', 3000.0)
# iteration 0 / 150: loss 51.444898
# iteration 100 / 150: loss 27.272326
# ('results[learn_rate, reg]', (0.26538775510204082, 0.26100000000000001))
#
# ('Learning rate:', 1e-06, 'Regularization strength:', 7000.0)
# iteration 0 / 150: loss 112.445002
# iteration 100 / 150: loss 27.606736
# ('results[learn_rate, reg]', (0.30865306122448982, 0.317))
#
# ('Learning rate:', 1e-06, 'Regularization strength:', 10000.0)
# iteration 0 / 150: loss 159.637360
# iteration 100 / 150: loss 22.406477
# ('results[learn_rate, reg]', (0.32451020408163267, 0.34200000000000003))
#
# ('Learning rate:', 1e-06, 'Regularization strength:', 13000.0)
# iteration 0 / 150: loss 204.470232
# iteration 100 / 150: loss 16.521796
# ('results[learn_rate, reg]', (0.3447142857142857, 0.34599999999999997))
#
# ('Learning rate:', 1e-06, 'Regularization strength:', 17000.0)
# iteration 0 / 150: loss 265.054110
# iteration 100 / 150: loss 10.312165
# ('results[learn_rate, reg]', (0.34224489795918367, 0.34699999999999998))
#
# ('Learning rate:', 1.2999999999999998e-06, 'Regularization strength:', 3000.0)
# iteration 0 / 150: loss 50.551830
# iteration 100 / 150: loss 22.916794
# ('results[learn_rate, reg]', (0.28908163265306125, 0.30399999999999999))
#
# ('Learning rate:', 1.2999999999999998e-06, 'Regularization strength:', 7000.0)
# iteration 0 / 150: loss 112.333173
# iteration 100 / 150: loss 18.958984
# ('results[learn_rate, reg]', (0.33279591836734695, 0.34300000000000003))
#
# ('Learning rate:', 1.2999999999999998e-06, 'Regularization strength:', 10000.0)
# iteration 0 / 150: loss 159.663353
# iteration 100 / 150: loss 13.026775
# ('results[learn_rate, reg]', (0.34057142857142858, 0.35199999999999998))
#
# ('Learning rate:', 1.2999999999999998e-06, 'Regularization strength:', 13000.0)
# iteration 0 / 150: loss 203.176932
# iteration 100 / 150: loss 8.353660
# ('results[learn_rate, reg]', (0.3431020408163265, 0.35599999999999998))
#
# ('Learning rate:', 1.2999999999999998e-06, 'Regularization strength:', 17000.0)
# iteration 0 / 150: loss 265.066824
# iteration 100 / 150: loss 4.858675
# ('results[learn_rate, reg]', (0.35010204081632651, 0.33700000000000002))
#
# ('Learning rate:', 1.6999999999999998e-06, 'Regularization strength:', 3000.0)
# iteration 0 / 150: loss 51.608113
# iteration 100 / 150: loss 18.525994
# ('results[learn_rate, reg]', (0.31712244897959185, 0.313))
#
# ('Learning rate:', 1.6999999999999998e-06, 'Regularization strength:', 7000.0)
# iteration 0 / 150: loss 114.718547
# iteration 100 / 150: loss 11.706789
# ('results[learn_rate, reg]', (0.35283673469387755, 0.36499999999999999))
#
# ('Learning rate:', 1.6999999999999998e-06, 'Regularization strength:', 10000.0)
# iteration 0 / 150: loss 160.255613
# iteration 100 / 150: loss 6.817516
# ('results[learn_rate, reg]', (0.35034693877551021, 0.35399999999999998))
#
# ('Learning rate:', 1.6999999999999998e-06, 'Regularization strength:', 13000.0)
# iteration 0 / 150: loss 203.880271
# iteration 100 / 150: loss 4.302617
# ('results[learn_rate, reg]', (0.3509591836734694, 0.34399999999999997))
#
# ('Learning rate:', 1.6999999999999998e-06, 'Regularization strength:', 17000.0)
# iteration 0 / 150: loss 265.973767
# iteration 100 / 150: loss 2.672275
# ('results[learn_rate, reg]', (0.33453061224489794, 0.34899999999999998))
#
# ('Loop', 2)
# ('Learning rates:', [5.1e-07, 1.19e-06, 1.6999999999999998e-06, 2.2099999999999996e-06, 2.8899999999999994e-06])
# ('Regularization strenghts:', [2100.0, 4900.0, 7000.0, 9100.0, 11900.0])
# ('Learning rate:', 5.1e-07, 'Regularization strength:', 2100.0)
# iteration 0 / 150: loss 38.093899
# iteration 100 / 150: loss 29.130104
# ('results[learn_rate, reg]', (0.23193877551020409, 0.223))
#
# ('Learning rate:', 5.1e-07, 'Regularization strength:', 4900.0)
# iteration 0 / 150: loss 81.763926
# iteration 100 / 150: loss 48.043781
# ('results[learn_rate, reg]', (0.24146938775510204, 0.245))
#
# ('Learning rate:', 5.1e-07, 'Regularization strength:', 7000.0)
# iteration 0 / 150: loss 113.186868
# iteration 100 / 150: loss 54.551020
# ('results[learn_rate, reg]', (0.24420408163265306, 0.26100000000000001))
#
# ('Learning rate:', 5.1e-07, 'Regularization strength:', 9100.0)
# iteration 0 / 150: loss 145.576665
# iteration 100 / 150: loss 57.159468
# ('results[learn_rate, reg]', (0.24387755102040817, 0.248))
#
# ('Learning rate:', 5.1e-07, 'Regularization strength:', 11900.0)
# iteration 0 / 150: loss 189.295731
# iteration 100 / 150: loss 56.111548
# ('results[learn_rate, reg]', (0.26071428571428573, 0.28100000000000003))
#
# ('Learning rate:', 1.19e-06, 'Regularization strength:', 2100.0)
# iteration 0 / 150: loss 38.827653
# iteration 100 / 150: loss 21.883012
# ('results[learn_rate, reg]', (0.27355102040816326, 0.30299999999999999))
#
# ('Learning rate:', 1.19e-06, 'Regularization strength:', 4900.0)
# iteration 0 / 150: loss 81.229543
# iteration 100 / 150: loss 25.044638
# ('results[learn_rate, reg]', (0.30320408163265306, 0.309))
#
# ('Learning rate:', 1.19e-06, 'Regularization strength:', 7000.0)
# iteration 0 / 150: loss 114.587796
# iteration 100 / 150: loss 22.154649
# ('results[learn_rate, reg]', (0.31891836734693879, 0.312))
#
# ('Learning rate:', 1.19e-06, 'Regularization strength:', 9100.0)
# iteration 0 / 150: loss 146.365994
# iteration 100 / 150: loss 17.620912
# ('results[learn_rate, reg]', (0.34693877551020408, 0.34499999999999997))
#
# ('Learning rate:', 1.19e-06, 'Regularization strength:', 11900.0)
# iteration 0 / 150: loss 188.527046
# iteration 100 / 150: loss 12.340957
# ('results[learn_rate, reg]', (0.34891836734693876, 0.34799999999999998))
#
# ('Learning rate:', 1.6999999999999998e-06, 'Regularization strength:', 2100.0)
# iteration 0 / 150: loss 38.117653
# iteration 100 / 150: loss 17.823979
# ('results[learn_rate, reg]', (0.30012244897959184, 0.314))
#
# ('Learning rate:', 1.6999999999999998e-06, 'Regularization strength:', 4900.0)
# iteration 0 / 150: loss 80.489368
# iteration 100 / 150: loss 15.816484
# ('results[learn_rate, reg]', (0.33622448979591835, 0.35999999999999999))
#
# ('Learning rate:', 1.6999999999999998e-06, 'Regularization strength:', 7000.0)
# iteration 0 / 150: loss 112.851645
# iteration 100 / 150: loss 11.486004
# ('results[learn_rate, reg]', (0.35355102040816327, 0.37))
#
# ('Learning rate:', 1.6999999999999998e-06, 'Regularization strength:', 9100.0)
# iteration 0 / 150: loss 146.120618
# iteration 100 / 150: loss 8.068508
# ('results[learn_rate, reg]', (0.35642857142857143, 0.36799999999999999))
#
# ('Learning rate:', 1.6999999999999998e-06, 'Regularization strength:', 11900.0)
# iteration 0 / 150: loss 186.448224
# iteration 100 / 150: loss 4.869629
# ('results[learn_rate, reg]', (0.35189795918367345, 0.36299999999999999))
#
# ('Learning rate:', 2.2099999999999996e-06, 'Regularization strength:', 2100.0)
# iteration 0 / 150: loss 38.369448
# iteration 100 / 150: loss 14.465715
# ('results[learn_rate, reg]', (0.32310204081632654, 0.32100000000000001))
#
# ('Learning rate:', 2.2099999999999996e-06, 'Regularization strength:', 4900.0)
# iteration 0 / 150: loss 81.189023
# iteration 100 / 150: loss 10.286312
# ('results[learn_rate, reg]', (0.34518367346938778, 0.34799999999999998))
#
# ('Learning rate:', 2.2099999999999996e-06, 'Regularization strength:', 7000.0)
# iteration 0 / 150: loss 112.787988
# iteration 100 / 150: loss 6.598853
# ('results[learn_rate, reg]', (0.35983673469387756, 0.372))
#
# ('Learning rate:', 2.2099999999999996e-06, 'Regularization strength:', 9100.0)
# iteration 0 / 150: loss 145.478624
# iteration 100 / 150: loss 4.285748
# ('results[learn_rate, reg]', (0.33732653061224488, 0.36099999999999999))
#
# ('Learning rate:', 2.2099999999999996e-06, 'Regularization strength:', 11900.0)
# iteration 0 / 150: loss 186.059662
# iteration 100 / 150: loss 2.856958
# ('results[learn_rate, reg]', (0.34246938775510205, 0.35299999999999998))
#
# ('Learning rate:', 2.8899999999999994e-06, 'Regularization strength:', 2100.0)
# iteration 0 / 150: loss 39.541933
# iteration 100 / 150: loss 11.339543
# ('results[learn_rate, reg]', (0.33506122448979592, 0.33100000000000002))
#
# ('Learning rate:', 2.8899999999999994e-06, 'Regularization strength:', 4900.0)
# iteration 0 / 150: loss 80.320896
# iteration 100 / 150: loss 6.096288
# ('results[learn_rate, reg]', (0.36273469387755103, 0.373))
#
# ('Learning rate:', 2.8899999999999994e-06, 'Regularization strength:', 7000.0)
# iteration 0 / 150: loss 114.737172
# iteration 100 / 150: loss 3.637768
# ('results[learn_rate, reg]', (0.35924489795918368, 0.34999999999999998))
#
# ('Learning rate:', 2.8899999999999994e-06, 'Regularization strength:', 9100.0)
# iteration 0 / 150: loss 145.903118
# iteration 100 / 150: loss 2.530921
# ('results[learn_rate, reg]', (0.34885714285714287, 0.35199999999999998))
#
# ('Learning rate:', 2.8899999999999994e-06, 'Regularization strength:', 11900.0)
# iteration 0 / 150: loss 189.165868
# iteration 100 / 150: loss 2.163534
# ('results[learn_rate, reg]', (0.33600000000000002, 0.34599999999999997))
#
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.160286 val accuracy: 0.144000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.166469 val accuracy: 0.167000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.199041 val accuracy: 0.194000
# lr 3.000000e-07 reg 3.000000e+03 train accuracy: 0.184633 val accuracy: 0.206000
# lr 3.000000e-07 reg 7.000000e+03 train accuracy: 0.215796 val accuracy: 0.224000
# lr 3.000000e-07 reg 1.000000e+04 train accuracy: 0.207184 val accuracy: 0.217000
# lr 3.000000e-07 reg 1.300000e+04 train accuracy: 0.220388 val accuracy: 0.227000
# lr 3.000000e-07 reg 1.700000e+04 train accuracy: 0.231653 val accuracy: 0.241000
# lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.260592 val accuracy: 0.243000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.325286 val accuracy: 0.329000
# lr 5.000000e-07 reg 1.000000e+05 train accuracy: 0.296531 val accuracy: 0.311000
# lr 5.100000e-07 reg 2.100000e+03 train accuracy: 0.231939 val accuracy: 0.223000
# lr 5.100000e-07 reg 4.900000e+03 train accuracy: 0.241469 val accuracy: 0.245000
# lr 5.100000e-07 reg 7.000000e+03 train accuracy: 0.244204 val accuracy: 0.261000
# lr 5.100000e-07 reg 9.100000e+03 train accuracy: 0.243878 val accuracy: 0.248000
# lr 5.100000e-07 reg 1.190000e+04 train accuracy: 0.260714 val accuracy: 0.281000
# lr 7.000000e-07 reg 3.000000e+03 train accuracy: 0.239755 val accuracy: 0.221000
# lr 7.000000e-07 reg 7.000000e+03 train accuracy: 0.268327 val accuracy: 0.271000
# lr 7.000000e-07 reg 1.000000e+04 train accuracy: 0.289408 val accuracy: 0.290000
# lr 7.000000e-07 reg 1.300000e+04 train accuracy: 0.310000 val accuracy: 0.301000
# lr 7.000000e-07 reg 1.700000e+04 train accuracy: 0.324000 val accuracy: 0.335000
# lr 1.000000e-06 reg 3.000000e+03 train accuracy: 0.265388 val accuracy: 0.261000
# lr 1.000000e-06 reg 7.000000e+03 train accuracy: 0.308653 val accuracy: 0.317000
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.324510 val accuracy: 0.342000
# lr 1.000000e-06 reg 1.300000e+04 train accuracy: 0.344714 val accuracy: 0.346000
# lr 1.000000e-06 reg 1.700000e+04 train accuracy: 0.342245 val accuracy: 0.347000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.315347 val accuracy: 0.319000
# lr 1.000000e-06 reg 1.000000e+05 train accuracy: 0.286612 val accuracy: 0.296000
# lr 1.190000e-06 reg 2.100000e+03 train accuracy: 0.273551 val accuracy: 0.303000
# lr 1.190000e-06 reg 4.900000e+03 train accuracy: 0.303204 val accuracy: 0.309000
# lr 1.190000e-06 reg 7.000000e+03 train accuracy: 0.318918 val accuracy: 0.312000
# lr 1.190000e-06 reg 9.100000e+03 train accuracy: 0.346939 val accuracy: 0.345000
# lr 1.190000e-06 reg 1.190000e+04 train accuracy: 0.348918 val accuracy: 0.348000
# lr 1.300000e-06 reg 3.000000e+03 train accuracy: 0.289082 val accuracy: 0.304000
# lr 1.300000e-06 reg 7.000000e+03 train accuracy: 0.332796 val accuracy: 0.343000
# lr 1.300000e-06 reg 1.000000e+04 train accuracy: 0.340571 val accuracy: 0.352000
# lr 1.300000e-06 reg 1.300000e+04 train accuracy: 0.343102 val accuracy: 0.356000
# lr 1.300000e-06 reg 1.700000e+04 train accuracy: 0.350102 val accuracy: 0.337000
# lr 1.700000e-06 reg 2.100000e+03 train accuracy: 0.300122 val accuracy: 0.314000
# lr 1.700000e-06 reg 3.000000e+03 train accuracy: 0.317122 val accuracy: 0.313000
# lr 1.700000e-06 reg 4.900000e+03 train accuracy: 0.336224 val accuracy: 0.360000
# lr 1.700000e-06 reg 7.000000e+03 train accuracy: 0.353551 val accuracy: 0.370000
# lr 1.700000e-06 reg 9.100000e+03 train accuracy: 0.356429 val accuracy: 0.368000
# lr 1.700000e-06 reg 1.000000e+04 train accuracy: 0.350347 val accuracy: 0.354000
# lr 1.700000e-06 reg 1.190000e+04 train accuracy: 0.351898 val accuracy: 0.363000
# lr 1.700000e-06 reg 1.300000e+04 train accuracy: 0.350959 val accuracy: 0.344000
# lr 1.700000e-06 reg 1.700000e+04 train accuracy: 0.334531 val accuracy: 0.349000
# lr 2.210000e-06 reg 2.100000e+03 train accuracy: 0.323102 val accuracy: 0.321000
# lr 2.210000e-06 reg 4.900000e+03 train accuracy: 0.345184 val accuracy: 0.348000
# lr 2.210000e-06 reg 7.000000e+03 train accuracy: 0.359837 val accuracy: 0.372000
# lr 2.210000e-06 reg 9.100000e+03 train accuracy: 0.337327 val accuracy: 0.361000
# lr 2.210000e-06 reg 1.190000e+04 train accuracy: 0.342469 val accuracy: 0.353000
# lr 2.890000e-06 reg 2.100000e+03 train accuracy: 0.335061 val accuracy: 0.331000
# lr 2.890000e-06 reg 4.900000e+03 train accuracy: 0.362735 val accuracy: 0.373000
# lr 2.890000e-06 reg 7.000000e+03 train accuracy: 0.359245 val accuracy: 0.350000
# lr 2.890000e-06 reg 9.100000e+03 train accuracy: 0.348857 val accuracy: 0.352000
# lr 2.890000e-06 reg 1.190000e+04 train accuracy: 0.336000 val accuracy: 0.346000
# lr 5.000000e-06 reg 1.000000e+04 train accuracy: 0.298327 val accuracy: 0.300000
# lr 5.000000e-06 reg 5.000000e+04 train accuracy: 0.216510 val accuracy: 0.224000
# lr 5.000000e-06 reg 1.000000e+05 train accuracy: 0.157592 val accuracy: 0.161000
# lr 1.000000e-05 reg 1.000000e+04 train accuracy: 0.231306 val accuracy: 0.244000
# lr 1.000000e-05 reg 5.000000e+04 train accuracy: 0.133367 val accuracy: 0.130000
# lr 1.000000e-05 reg 1.000000e+05 train accuracy: 0.075531 val accuracy: 0.079000
# lr 5.000000e-05 reg 1.000000e+04 train accuracy: 0.119837 val accuracy: 0.115000
# lr 5.000000e-05 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.373000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print 'softmax on raw pixels final test set accuracy: %f' % (test_accuracy, )
# Out:
# softmax on raw pixels final test set accuracy: 0.368000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
  
  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
